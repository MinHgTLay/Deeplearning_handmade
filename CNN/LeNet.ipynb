# %%
import torch
from torch import nn
from d2l import torch as d2l

net = nn.Sequential(
    nn.Conv2d(1, 6, kernel_size=5, padding=2), nn.ReLU(),
    nn.Conv2d(6, 16, kernel_size=5), nn.Sigmoid(),
    nn.AvgPool2d(kernel_size=2, stride=2),
    nn.Flatten(),
    nn.Linear(16 * 12 * 12, 120), nn.ReLU(),
    nn.Linear(120, 84), nn.Sigmoid(),
    nn.Linear(84, 10))

# %%
X = torch.rand(size=(1, 1, 28, 28), dtype=torch.float32)
for layer in net:
    X = layer(X)
    print(layer.__class__.__name__,'output shape: \t',X.shape)
# Out:
# Conv2d output shape: 	 torch.Size([1, 6, 28, 28])
# Sigmoid output shape: 	 torch.Size([1, 6, 28, 28])
# Conv2d output shape: 	 torch.Size([1, 16, 24, 24])
# ReLU output shape: 	 torch.Size([1, 16, 24, 24])
# AvgPool2d output shape: 	 torch.Size([1, 16, 12, 12])
# Flatten output shape: 	 torch.Size([1, 2304])
# Linear output shape: 	 torch.Size([1, 120])
# Sigmoid output shape: 	 torch.Size([1, 120])
# Linear output shape: 	 torch.Size([1, 84])
# ReLU output shape: 	 torch.Size([1, 84])
# Linear output shape: 	 torch.Size([1, 10])

# %%
batch_size = 256
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size=batch_size)

# %%
def evaluate_accuracy_gpu(net, data_iter, device=None): #@save
    """使用GPU计算模型在数据集上的精度"""
    if isinstance(net, nn.Module):
        net.eval()  # 设置为评估模式
        if not device:
            device = next(iter(net.parameters())).device
    # 正确预测的数量，总预测的数量
    metric = d2l.Accumulator(2)
    with torch.no_grad():
        for X, y in data_iter:
            if isinstance(X, list):
                # BERT微调所需的（之后将介绍）
                X = [x.to(device) for x in X]
            else:
                X = X.to(device)
            y = y.to(device)
            metric.add(d2l.accuracy(net(X), y), y.numel())
    return metric[0] / metric[1]

# %%
#@save
def train_ch6(net, train_iter, test_iter, num_epochs, lr, device):
    """用GPU训练模型(在第六章定义)"""
    def init_weights(m):
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            nn.init.xavier_uniform_(m.weight)
    net.apply(init_weights)
    print('training on', device)
    net.to(device)
    optimizer = torch.optim.SGD(net.parameters(), lr=lr)
    loss = nn.CrossEntropyLoss()
    animator = d2l.Animator(xlabel='epoch', xlim=[1, num_epochs],
                            legend=['train loss', 'train acc', 'test acc'])
    timer, num_batches = d2l.Timer(), len(train_iter)
    for epoch in range(num_epochs):
        # 训练损失之和，训练准确率之和，样本数
        metric = d2l.Accumulator(3)
        net.train()
        for i, (X, y) in enumerate(train_iter):
            timer.start()
            optimizer.zero_grad()
            X, y = X.to(device), y.to(device)
            y_hat = net(X)
            l = loss(y_hat, y)
            l.backward()
            optimizer.step()
            with torch.no_grad():
                metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
            timer.stop()
            train_l = metric[0] / metric[2]
            train_acc = metric[1] / metric[2]
            if (i + 1) % (num_batches // 5) == 0 or i == num_batches - 1:
                animator.add(epoch + (i + 1) / num_batches,
                             (train_l, train_acc, None))
        test_acc = evaluate_accuracy_gpu(net, test_iter)
        animator.add(epoch + 1, (None, None, test_acc))
    print(f'loss {train_l:.3f}, train acc {train_acc:.3f}, '
          f'test acc {test_acc:.3f}')
    print(f'{metric[2] * num_epochs / timer.sum():.1f} examples/sec '
          f'on {str(device)}')

# %%
lr, num_epochs = 1, 10
train_ch6(net, train_iter, test_iter, num_epochs, lr, d2l.try_gpu())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[74], line 2
#       1 lr, num_epochs = 1, 10
# ----> 2 train_ch6(net, train_iter, test_iter, num_epochs, lr, d2l.try_gpu())
#
# Cell In[73], line 19, in train_ch6(net, train_iter, test_iter, num_epochs, lr, device)
#      17 metric = d2l.Accumulator(3)
#      18 net.train()
# ---> 19 for i, (X, y) in enumerate(train_iter):
#      20     timer.start()
#      21     optimizer.zero_grad()
#
# File c:\Conda\miniconda3\envs\d2l_python3.9\lib\site-packages\torch\utils\data\dataloader.py:732, in _BaseDataLoaderIter.__next__(self)
#     729 if self._sampler_iter is None:
#     730     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731     self._reset()  # type: ignore[call-arg]
# --> 732 data = self._next_data()
#     733 self._num_yielded += 1
#     734 if (
#     735     self._dataset_kind == _DatasetKind.Iterable
#     736     and self._IterableDataset_len_called is not None
#     737     and self._num_yielded > self._IterableDataset_len_called
#     738 ):
#
# File c:\Conda\miniconda3\envs\d2l_python3.9\lib\site-packages\torch\utils\data\dataloader.py:1490, in _MultiProcessingDataLoaderIter._next_data(self)
#    1487     return self._process_data(data, worker_id)
#    1489 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1490 idx, data = self._get_data()
#    1491 self._tasks_outstanding -= 1
#    1492 if self._dataset_kind == _DatasetKind.Iterable:
#    1493     # Check for _IterableDatasetStopIteration
#
# File c:\Conda\miniconda3\envs\d2l_python3.9\lib\site-packages\torch\utils\data\dataloader.py:1452, in _MultiProcessingDataLoaderIter._get_data(self)
#    1448     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1449     # need to call `.task_done()` because we don't use `.join()`.
#    1450 else:
#    1451     while True:
# -> 1452         success, data = self._try_get_data()
#    1453         if success:
#    1454             return data
#
# File c:\Conda\miniconda3\envs\d2l_python3.9\lib\site-packages\torch\utils\data\dataloader.py:1283, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1270 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1271     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1272     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1280     # Returns a 2-tuple:
#    1281     #   (bool: whether successfully get data, any: data if successful else None)
#    1282     try:
# -> 1283         data = self._data_queue.get(timeout=timeout)
#    1284         return (True, data)
#    1285     except Exception as e:
#    1286         # At timeout and error, we manually check whether any worker has
#    1287         # failed. Note that this is the only mechanism for Windows to detect
#    1288         # worker failures.
#
# File c:\Conda\miniconda3\envs\d2l_python3.9\lib\multiprocessing\queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File c:\Conda\miniconda3\envs\d2l_python3.9\lib\multiprocessing\connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File c:\Conda\miniconda3\envs\d2l_python3.9\lib\multiprocessing\connection.py:330, in PipeConnection._poll(self, timeout)
#     327 if (self._got_empty_message or
#     328             _winapi.PeekNamedPipe(self._handle)[0] != 0):
#     329     return True
# --> 330 return bool(wait([self], timeout))
#
# File c:\Conda\miniconda3\envs\d2l_python3.9\lib\multiprocessing\connection.py:879, in wait(object_list, timeout)
#     876                 ready_objects.add(o)
#     877                 timeout = 0
# --> 879     ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#     880 finally:
#     881     # request that overlapped reads stop
#     882     for ov in ov_list:
#
# File c:\Conda\miniconda3\envs\d2l_python3.9\lib\multiprocessing\connection.py:811, in _exhaustive_wait(handles, timeout)
#     809 ready = []
#     810 while L:
# --> 811     res = _winapi.WaitForMultipleObjects(L, False, timeout)
#     812     if res == WAIT_TIMEOUT:
#     813         break
#
# KeyboardInterrupt:
